# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/NanumSquareRoundL.ttf").get_name()
rc('font', family=font_name)

# %%
import librosa
import librosa.display
import IPython.display
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
 
# %matplotlib inline
 
audio_path = 'jeollado0001.wav'
y, sr = librosa.load(audio_path,offset=10, duration=10)

# %% [markdown]
# ### WAV 원본 그대로

# %%
D = librosa.amplitude_to_db(librosa.stft(y[:1024]), ref=np.max)

log_S = librosa.amplitude_to_db(D, ref=np.max)
pcen_S = librosa.pcen(S * (2**31))
plt.figure(figsize=(12, 10))
plt.subplot(2,1,1)
librosa.display.specshow(log_S, x_axis='time', y_axis='mel')
plt.title('log amplitude (dB)')
plt.colorbar()
plt.subplot(2,1,2)
librosa.display.specshow(pcen_S, x_axis='time', y_axis='mel')
plt.title('Per-channel energy normalization')
plt.colorbar()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### MFCC 변환

# %%
S = librosa.feature.mfcc(y, sr=24000, n_mfcc=13)

log_S = librosa.amplitude_to_db(S, ref=np.max)
pcen_S = librosa.pcen(S * (2**31))
plt.figure(figsize=(12, 10))
plt.subplot(2,1,1)
librosa.display.specshow(log_S, x_axis='time', y_axis='mel')
plt.title('log amplitude (dB)')
plt.colorbar()
plt.subplot(2,1,2)
librosa.display.specshow(pcen_S, x_axis='time', y_axis='mel')
plt.title('Per-channel energy normalization')
plt.colorbar()
plt.tight_layout()
plt.show()
